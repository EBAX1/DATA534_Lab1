# %%
import pandas as pd
import time
from urllib.request import urlopen
import requests
from bs4 import BeautifulSoup
from graphviz import Digraph
import re
import time

# %% [markdown]
# # Web and Cloud Computing (DATA 534): Lab 1
# ## General Lab Instructions
#
# - This assignment is to be completed in python, submitting both a `.ipynb` file (you can add your answers directly to this one) along with a rendered `.md`.
# - I added an Intro section to help you with the basics for this lab. If you are already comfortable with scrapping data using python, you can safely skip it.

# %% [markdown]
# ## Intro
#
# Let's have this intro section to introduce you to the main python functions to deal with web scrapping and crawling.

# %% [markdown]
# ### Web requests
#
# When you navigate to a website, there are many things going on under the hood. Many layers of protocols are used to allow you to communicate with a web server (take a look at the [OSI model](https://en.wikipedia.org/wiki/OSI_model) if you are curious). We will be mostly dealing with the last layer (Layer 7 - [application layer](https://en.wikipedia.org/wiki/Application_layer)) and [HTTP](https://en.wikipedia.org/wiki/Hypertext_Transfer_Protocol) (HyperText Transfer Protocol). We'll leave for the python libraries to handle the details of the other layers for us.
#
# HTTP is text based. For example, to send a GET request to a web server:
# ```
# GET /HTTP/1.1
# Host: www.google.com
# User-Agent: Python-urllib/3.6
# ```
# and the server send back a response, also with a header and the requested content.
#
# Here we will use python (instead of a web browser like Chrome) to collect information from the web. For illustration purposes, let's scrap historical data of the Word Cups (soccer) available in [this wikipedia page](https://en.wikipedia.org/wiki/List_of_FIFA_World_Cup_winners).

# %% [markdown]
# #### The `urllib` package
#
# The [`urllib`](https://docs.python.org/3/library/urllib.html) is a built-in package in python focused on dealing with URLs. To open and read URLs, we use the function [`urllib.request.urlopen`](https://docs.python.org/3/library/urllib.request.html#module-urllib.request). Let's start by importing this function.

# %%
from urllib.request import urlopen

# %% [markdown]
# Ok, now all we have to do is to call the function and pass the URL we want. Note that although we don't usually need to add the "http://" when we are using a web browser, here we do (try removing this part if you are curious).

# %%
soccer_urllib = urlopen("https://en.wikipedia.org/wiki/List_of_FIFA_World_Cup_winners")

# %% [markdown]
# Now our `soccer_urllib` contains some information of our request. For example:

# %%
print("The url of our request: ", end="")
print(soccer_urllib.geturl())
# Out:
# The url of our request: https://en.wikipedia.org/wiki/List_of_FIFA_World_Cup_winners

# %% [markdown]
# We can also get the header from the server's response (don't need to spend a lot of time trying to understand this header - it is just to show you how to access this info):

# %%
print(soccer_urllib.info())
# Out:
# Date: Tue, 19 Jan 2021 15:04:58 GMT
# Server: mw1271.eqiad.wmnet
# X-Content-Type-Options: nosniff
# P3p: CP="See https://en.wikipedia.org/wiki/Special:CentralAutoLogin/P3P for more info."
# Content-Language: en
# Vary: Accept-Encoding,Cookie,Authorization
# X-Request-Id: YAb1GgpAAEIAADO9rJoAAABC
# Last-Modified: Thu, 14 Jan 2021 18:32:40 GMT
# Content-Type: text/html; charset=UTF-8
# Age: 46087
# X-Cache: cp4032 miss, cp4032 hit/1
# X-Cache-Status: hit-front
# Server-Timing: cache;desc="hit-front"
# Strict-Transport-Security: max-age=106384710; includeSubDomains; preload
# Report-To: { "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }
# NEL: { "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}
# Set-Cookie: WMF-Last-Access=20-Jan-2021;Path=/;HttpOnly;secure;Expires=Sun, 21 Feb 2021 00:00:00 GMT
# Set-Cookie: WMF-Last-Access-Global=20-Jan-2021;Path=/;Domain=.wikipedia.org;HttpOnly;secure;Expires=Sun, 21 Feb 2021 00:00:00 GMT
# X-Client-IP: 74.3.136.253
# Cache-Control: private, s-maxage=0, max-age=0, must-revalidate
# Set-Cookie: GeoIP=CA:BC:Kelowna:49.95:-119.43:v4; Path=/; secure; Domain=.wikipedia.org
# Accept-Ranges: bytes
# Content-Length: 811548
# Connection: close

# %% [markdown]
# Ok, but what about the content of the page? Let's check it out!

# %%
# soccer_html = soccer_urllib.read()
# print(soccer_html)

# %% [markdown]
# Yes, it is a complete mess, I know. How to make sense of all this? Well, there are different approaches. We could use regular expression (not a good idea though), or we could use python packages such as [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) and [lxml](https://lxml.de/tutorial.html) to help you make sense of this thing. Here we will focus on `BeautifulSoup`, but you have seen `lxml` in 513, remember?
#
# We have to be careful when using `urllib.request.open`, because if you request a webpage that does not exist, it will throw an exception and stop your program. Try running the commented code in the following cell:

# %%
#my_pg = urlopen("www.lourenzu.com")

# %% [markdown]
# The exceptions raised by `urllib.request` are defined in [`urllib.error`](https://docs.python.org/3/library/urllib.error.html#module-urllib.error). So we can import this package and make a more robust piece of code that handles these exceptions:

# %%
from urllib.error import HTTPError, URLError
try:
    my_pg = urlopen("http://www.lourenzu.com")
except URLError as error:
    print(error.reason)
# Out:
# [Errno 11001] getaddrinfo failed

# %%
try:
    my_pg = urlopen("http://www.google.com/rodolfo_lourenzutti")
except HTTPError as error:
    print("The famous error code: ", error.code)
    print("The reason for the exception:", error.reason)
# Out:
# The famous error code:  404
# The reason for the exception: Not Found

# %% [markdown]
# Handling exceptions is an important part of web scrapping. Let's see an alternative package next.

# %% [markdown]
# #### The `requests` package

# %% [markdown]
# The [`requests`](http://docs.python-requests.org/en/master/user/quickstart/#custom-headers) package is an alternative (not built-in) HTTP library that is becoming more and more popular. Let's load the package and request our wikipedia page:

# %%
import requests

soccer_requests = requests.get("https://en.wikipedia.org/wiki/List_of_FIFA_World_Cup_winners")

# %% [markdown]
# Differently from the `urllib`, requests does not raise an exception for HTTP errors:

# %%
bad_request = requests.get("http://www.google.com/rodolfo_lourenzutti")
bad_request
# Out:
# <Response [404]>

# %% [markdown]
# But it does raise an exception for some errors (uncomment the line below to see):

# %%
# requests.get("http://www.lourenzu.com")

# %% [markdown]
# Now, let's check the status code of our wikipedia request:

# %%
soccer_requests.status_code
# Out:
# 200

# %%
soccer_requests.reason
# Out:
# 'OK'

# %% [markdown]
# Great! Code 200 means everything is ok! We can also check the headers of the request and of the response:

# %%
# Headers of the request
print(soccer_requests.request.headers)
# Out:
# {'User-Agent': 'python-requests/2.24.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %% [markdown]
# Lastly, let's access the content of the page:

# %%
# Headers of the response
soccer_requests.headers
# Out:
# {'Date': 'Tue, 19 Jan 2021 15:04:58 GMT', 'Server': 'mw1271.eqiad.wmnet', 'X-Content-Type-Options': 'nosniff', 'P3p': 'CP="See https://en.wikipedia.org/wiki/Special:CentralAutoLogin/P3P for more info."', 'Content-Language': 'en', 'Vary': 'Accept-Encoding,Cookie,Authorization', 'X-Request-Id': 'YAb1GgpAAEIAADO9rJoAAABC', 'Last-Modified': 'Thu, 14 Jan 2021 18:32:40 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Content-Encoding': 'gzip', 'Age': '46515', 'X-Cache': 'cp4032 miss, cp4032 hit/2', 'X-Cache-Status': 'hit-front', 'Server-Timing': 'cache;desc="hit-front"', 'Strict-Transport-Security': 'max-age=106384710; includeSubDomains; preload', 'Report-To': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'NEL': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'Set-Cookie': 'WMF-Last-Access=20-Jan-2021;Path=/;HttpOnly;secure;Expires=Sun, 21 Feb 2021 00:00:00 GMT, WMF-Last-Access-Global=20-Jan-2021;Path=/;Domain=.wikipedia.org;HttpOnly;secure;Expires=Sun, 21 Feb 2021 00:00:00 GMT, GeoIP=CA:BC:Kelowna:49.95:-119.43:v4; Path=/; secure; Domain=.wikipedia.org', 'X-Client-IP': '74.3.136.253', 'Cache-Control': 'private, s-maxage=0, max-age=0, must-revalidate', 'Accept-Ranges': 'bytes', 'Content-Length': '66755', 'Connection': 'keep-alive'}

# %%
#soccer_requests.text

# %% [markdown]
# ### Beautiful Soup
#
# [`BeautifulSoup`](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) is a quite useful package to handle data in HTML format. It has two main functions
# 1. [`BeautifulSoup.find()`](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find)
# 2. [`BeautifulSoup.find_all()`](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-all)
#
# There are other functions that might be useful as well (e.g., `find_next_sibling()`, `find_parent()`)
#
# Let's starting by importing the library and creating a `BeautifulSoup` object.

# %%
from bs4 import BeautifulSoup

# %%
# Creating a BeautifulSoup object.
soccer = BeautifulSoup(soccer_requests.text) # remember that the field text contains the content of our request

# %% [markdown]
# Great! Now we have a `BeautifulSoup` object stored in the `soccer` variable. We can now use the function `find_all()` to retrieve information. For example, let's find the tables contained in the page.

# %%
tables = soccer.find_all("table")
tables
# Out:
# [<table class="wikitable plainrowheaders sortable">
#  <caption>Players who have won the World Cup
#  </caption>
#  <tbody><tr>
#  <th rowspan="2" scope="col">Player
#  </th>
#  <th rowspan="2" scope="col">Team
#  </th>
#  <th rowspan="2" scope="col">Titles won
#  </th>
#  <th rowspan="2" scope="col">Year(s)
#  </th>
#  <th colspan="2" scope="col">Other appearances
#  </th>
#  <th class="unsortable" rowspan="2" scope="col">Profile
#  </th></tr>
#  <tr>
#  <th scope="col">As player
#  </th>
#  <th scope="col">As manager
#  </th></tr>
#  <tr>
#  <th data-sort-value="Pele" scope="row"><a href="/wiki/Pel%C3%A9" title="Pelé">Pelé</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="504" data-file-width="720" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/2e/Flag_of_Brazil_%281968%E2%80%931992%29.svg/22px-Flag_of_Brazil_%281968%E2%80%931992%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/2e/Flag_of_Brazil_%281968%E2%80%931992%29.svg/33px-Flag_of_Brazil_%281968%E2%80%931992%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/2e/Flag_of_Brazil_%281968%E2%80%931992%29.svg/43px-Flag_of_Brazil_%281968%E2%80%931992%29.svg.png 2x" width="22"/> </span><a href="/wiki/Brazil_national_football_team" title="Brazil national football team">Brazil</a></span>
#  </td>
#  <td style="text-align: center;">3
#  </td>
#  <td><b>1958</b>, 1962, <b>1970</b>
#  </td>
#  <td>1966
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[fp 1]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Bellini" scope="row"><a href="/wiki/Hilderaldo_Bellini" title="Hilderaldo Bellini">Bellini</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="504" data-file-width="720" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/22px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/33px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/43px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 2x" width="22"/> </span><a href="/wiki/Brazil_national_football_team" title="Brazil national football team">Brazil</a></span>
#  </td>
#  <td style="text-align: center;">2
#  </td>
#  <td><b>1958</b>, <i>1962</i>
#  </td>
#  <td>1966
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[fp 2]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Cafu" scope="row"><a href="/wiki/Cafu" title="Cafu">Cafu</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="504" data-file-width="720" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/0/05/Flag_of_Brazil.svg/22px-Flag_of_Brazil.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/05/Flag_of_Brazil.svg/33px-Flag_of_Brazil.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/05/Flag_of_Brazil.svg/43px-Flag_of_Brazil.svg.png 2x" width="22"/> </span><a href="/wiki/Brazil_national_football_team" title="Brazil national football team">Brazil</a></span>
#  </td>
#  <td style="text-align: center;">2
#  </td>
#  <td><b>1994</b>, <b>2002</b>
#  </td>
#  <td>1998, 2006
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[fp 3]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Castilho" scope="row"><a href="/wiki/Carlos_Jos%C3%A9_Castilho" title="Carlos José Castilho">Castilho</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="504" data-file-width="720" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/22px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/33px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/43px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 2x" width="22"/> </span><a href="/wiki/Brazil_national_football_team" title="Brazil national football team">Brazil</a></span>
#  </td>
#  <td style="text-align: center;">2
#  </td>
#  <td><i>1958</i>, <i>1962</i>
#  </td>
#  <td><i>1950</i>, 1954
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-4"><a href="#cite_note-4">[fp 4]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Didi" scope="row"><a href="/wiki/Didi_(footballer,_born_1928)" title="Didi (footballer, born 1928)">Didi</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="504" data-file-width="720" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/22px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/33px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/43px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 2x" width="22"/> </span><a href="/wiki/Brazil_national_football_team" title="Brazil national football team">Brazil</a></span>
#  </td>
#  <td style="text-align: center;">2
#  </td>
#  <td><b>1958</b>, <b>1962</b>
#  </td>
#  <td>1954
#  </td>
#  <td>1970 <small><a href="/wiki/Peru_national_football_team" title="Peru national football team">PER</a></small>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-5"><a href="#cite_note-5">[fp 5]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Djalma Santos" scope="row"><a href="/wiki/Djalma_Santos" title="Djalma Santos">Djalma Santos</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="504" data-file-width="720" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/22px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/33px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/43px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 2x" width="22"/> </span><a href="/wiki/Brazil_national_football_team" title="Brazil national football team">Brazil</a></span>
#  </td>
#  <td style="text-align: center;">2
#  </td>
#  <td><b>1958</b>, <b>1962</b>
#  </td>
#  <td>1954, 1966
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-6"><a href="#cite_note-6">[fp 6]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Ferrari, Giovanni" scope="row"><a href="/wiki/Giovanni_Ferrari" title="Giovanni Ferrari">Giovanni Ferrari</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="1000" data-file-width="1500" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/78/Flag_of_Italy_%281861%E2%80%931946%29.svg/23px-Flag_of_Italy_%281861%E2%80%931946%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/78/Flag_of_Italy_%281861%E2%80%931946%29.svg/35px-Flag_of_Italy_%281861%E2%80%931946%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/78/Flag_of_Italy_%281861%E2%80%931946%29.svg/45px-Flag_of_Italy_%281861%E2%80%931946%29.svg.png 2x" width="23"/> </span><a href="/wiki/Italy_national_football_team" title="Italy national football team">Italy</a></span>
#  </td>
#  <td style="text-align: center;">2
#  </td>
#  <td><b>1934</b>, <b>1938</b>
#  </td>
#  <td>
#  </td>
#  <td>1962 <small><a href="/wiki/Italy_national_football_team" title="Italy national football team">ITA</a></small>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-7"><a href="#cite_note-7">[fp 7]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Garrincha" scope="row"><a href="/wiki/Garrincha" title="Garrincha">Garrincha</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="504" data-file-width="720" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/22px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/33px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/43px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 2x" width="22"/> </span><a href="/wiki/Brazil_national_football_team" title="Brazil national football team">Brazil</a></span>
#  </td>
#  <td style="text-align: center;">2
#  </td>
#  <td><b>1958</b>, <b>1962</b>
#  </td>
#  <td>1966
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-8"><a href="#cite_note-8">[fp 8]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Gilmar" scope="row"><a href="/wiki/Gylmar_dos_Santos_Neves" title="Gylmar dos Santos Neves">Gilmar</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="504" data-file-width="720" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/22px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/33px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/43px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 2x" width="22"/> </span><a href="/wiki/Brazil_national_football_team" title="Brazil national football team">Brazil</a></span>
#  </td>
#  <td style="text-align: center;">2
#  </td>
#  <td><b>1958</b>, <b>1962</b>
#  </td>
#  <td>1966
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-9"><a href="#cite_note-9">[fp 9]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Masetti, Guido" scope="row"><a href="/wiki/Guido_Masetti" title="Guido Masetti">Guido Masetti</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="1000" data-file-width="1500" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/78/Flag_of_Italy_%281861%E2%80%931946%29.svg/23px-Flag_of_Italy_%281861%E2%80%931946%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/78/Flag_of_Italy_%281861%E2%80%931946%29.svg/35px-Flag_of_Italy_%281861%E2%80%931946%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/78/Flag_of_Italy_%281861%E2%80%931946%29.svg/45px-Flag_of_Italy_%281861%E2%80%931946%29.svg.png 2x" width="23"/> </span><a href="/wiki/Italy_national_football_team" title="Italy national football team">Italy</a></span>
#  </td>
#  <td style="text-align: center;">2
#  </td>
#  <td><i>1934</i>, <i>1938</i>
#  </td>
#  <td>
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-10"><a href="#cite_note-10">[fp 10]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Mauro" scope="row"><a href="/wiki/Mauro_Ramos" title="Mauro Ramos">Mauro</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="504" data-file-width="720" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/22px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/33px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/43px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 2x" width="22"/> </span><a href="/wiki/Brazil_national_football_team" title="Brazil national football team">Brazil</a></span>
#  </td>
#  <td style="text-align: center;">2
#  </td>
#  <td><i>1958</i>, <b>1962</b>
#  </td>
#  <td><i>1954</i>
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-11"><a href="#cite_note-11">[fp 11]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Meazza, Giuseppe" scope="row"><a href="/wiki/Giuseppe_Meazza" title="Giuseppe Meazza">Giuseppe Meazza</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="1000" data-file-width="1500" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/78/Flag_of_Italy_%281861%E2%80%931946%29.svg/23px-Flag_of_Italy_%281861%E2%80%931946%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/78/Flag_of_Italy_%281861%E2%80%931946%29.svg/35px-Flag_of_Italy_%281861%E2%80%931946%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/78/Flag_of_Italy_%281861%E2%80%931946%29.svg/45px-Flag_of_Italy_%281861%E2%80%931946%29.svg.png 2x" width="23"/> </span><a href="/wiki/Italy_national_football_team" title="Italy national football team">Italy</a></span>
#  </td>
#  <td style="text-align: center;">2
#  </td>
#  <td><b>1934</b>, <b>1938</b>
#  </td>
#  <td>
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-12"><a href="#cite_note-12">[fp 12]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Monzeglio, Eraldo" scope="row"><a href="/wiki/Eraldo_Monzeglio" title="Eraldo Monzeglio">Eraldo Monzeglio</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="1000" data-file-width="1500" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/78/Flag_of_Italy_%281861%E2%80%931946%29.svg/23px-Flag_of_Italy_%281861%E2%80%931946%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/78/Flag_of_Italy_%281861%E2%80%931946%29.svg/35px-Flag_of_Italy_%281861%E2%80%931946%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/78/Flag_of_Italy_%281861%E2%80%931946%29.svg/45px-Flag_of_Italy_%281861%E2%80%931946%29.svg.png 2x" width="23"/> </span><a href="/wiki/Italy_national_football_team" title="Italy national football team">Italy</a></span>
#  </td>
#  <td style="text-align: center;">2
#  </td>
#  <td><b>1934</b>, 1938
#  </td>
#  <td>
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-13"><a href="#cite_note-13">[fp 13]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Nilton Santos" scope="row"><a href="/wiki/N%C3%ADlton_Santos" title="Nílton Santos">Nílton Santos</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="504" data-file-width="720" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/22px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/33px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/43px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 2x" width="22"/> </span><a href="/wiki/Brazil_national_football_team" title="Brazil national football team">Brazil</a></span>
#  </td>
#  <td style="text-align: center;">2
#  </td>
#  <td><b>1958</b>, <b>1962</b>
#  </td>
#  <td><i>1950</i>, 1954
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-14"><a href="#cite_note-14">[fp 14]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Passarella, Daniel" scope="row"><a href="/wiki/Daniel_Passarella" title="Daniel Passarella">Daniel Passarella</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="500" data-file-width="800" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_Argentina.svg/23px-Flag_of_Argentina.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_Argentina.svg/35px-Flag_of_Argentina.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_Argentina.svg/46px-Flag_of_Argentina.svg.png 2x" width="23"/> </span><a href="/wiki/Argentina_national_football_team" title="Argentina national football team">Argentina</a></span>
#  </td>
#  <td style="text-align: center;">2
#  </td>
#  <td><b>1978</b>, <i>1986</i>
#  </td>
#  <td>1982
#  </td>
#  <td>1998 <small><a href="/wiki/Argentina_national_football_team" title="Argentina national football team">ARG</a></small>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-15"><a href="#cite_note-15">[fp 15]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Pepe" scope="row"><a href="/wiki/Pepe_(footballer,_born_1935)" title="Pepe (footballer, born 1935)">Pepe</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="504" data-file-width="720" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/22px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/33px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/43px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 2x" width="22"/> </span><a href="/wiki/Brazil_national_football_team" title="Brazil national football team">Brazil</a></span>
#  </td>
#  <td style="text-align: center;">2
#  </td>
#  <td><i>1958</i>, <i>1962</i>
#  </td>
#  <td>
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-16"><a href="#cite_note-16">[fp 16]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Ronaldo" scope="row"><a href="/wiki/Ronaldo_(Brazilian_footballer)" title="Ronaldo (Brazilian footballer)">Ronaldo</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="504" data-file-width="720" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/0/05/Flag_of_Brazil.svg/22px-Flag_of_Brazil.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/05/Flag_of_Brazil.svg/33px-Flag_of_Brazil.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/05/Flag_of_Brazil.svg/43px-Flag_of_Brazil.svg.png 2x" width="22"/> </span><a href="/wiki/Brazil_national_football_team" title="Brazil national football team">Brazil</a></span>
#  </td>
#  <td style="text-align: center;">2
#  </td>
#  <td><i>1994</i>, <b>2002</b>
#  </td>
#  <td>1998, 2006
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-17"><a href="#cite_note-17">[fp 17]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Vava" scope="row"><a href="/wiki/Vav%C3%A1" title="Vavá">Vavá</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="504" data-file-width="720" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/22px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/33px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/43px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 2x" width="22"/> </span><a href="/wiki/Brazil_national_football_team" title="Brazil national football team">Brazil</a></span>
#  </td>
#  <td style="text-align: center;">2
#  </td>
#  <td><b>1958</b>, <b>1962</b>
#  </td>
#  <td>
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-18"><a href="#cite_note-18">[fp 18]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Zagallo, Mario" scope="row"><a href="/wiki/M%C3%A1rio_Zagallo" title="Mário Zagallo">Mário Zagallo</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="504" data-file-width="720" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/22px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/33px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/43px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 2x" width="22"/> </span><a href="/wiki/Brazil_national_football_team" title="Brazil national football team">Brazil</a></span>
#  </td>
#  <td style="text-align: center;">2
#  </td>
#  <td><b>1958</b>, <b>1962</b>
#  </td>
#  <td>
#  </td>
#  <td><span style="background-color:gold; color:;">1970 <small><a href="/wiki/Brazil_national_football_team" title="Brazil national football team">BRA</a></small></span>, 1974 <small><a href="/wiki/Brazil_national_football_team" title="Brazil national football team">BRA</a></small>, 1998 <small><a href="/wiki/Brazil_national_football_team" title="Brazil national football team">BRA</a></small>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-19"><a href="#cite_note-19">[fp 19]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Zito" scope="row"><a href="/wiki/Zito_(footballer)" title="Zito (footballer)">Zito</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="504" data-file-width="720" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/22px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/33px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/43px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 2x" width="22"/> </span><a href="/wiki/Brazil_national_football_team" title="Brazil national football team">Brazil</a></span>
#  </td>
#  <td style="text-align: center;">2
#  </td>
#  <td><b>1958</b>, <b>1962</b>
#  </td>
#  <td><i>1966</i>
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-20"><a href="#cite_note-20">[fp 20]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Zozimo" scope="row"><a href="/wiki/Z%C3%B3zimo" title="Zózimo">Zózimo</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="504" data-file-width="720" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/22px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/33px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/43px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 2x" width="22"/> </span><a href="/wiki/Brazil_national_football_team" title="Brazil national football team">Brazil</a></span>
#  </td>
#  <td style="text-align: center;">2
#  </td>
#  <td><i>1958</i>, <b>1962</b>
#  </td>
#  <td>
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-21"><a href="#cite_note-21">[fp 21]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Ado" scope="row"><a href="/wiki/Ado_(footballer)" title="Ado (footballer)">Ado</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="504" data-file-width="720" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/2e/Flag_of_Brazil_%281968%E2%80%931992%29.svg/22px-Flag_of_Brazil_%281968%E2%80%931992%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/2e/Flag_of_Brazil_%281968%E2%80%931992%29.svg/33px-Flag_of_Brazil_%281968%E2%80%931992%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/2e/Flag_of_Brazil_%281968%E2%80%931992%29.svg/43px-Flag_of_Brazil_%281968%E2%80%931992%29.svg.png 2x" width="22"/> </span><a href="/wiki/Brazil_national_football_team" title="Brazil national football team">Brazil</a></span>
#  </td>
#  <td style="text-align: center;">1
#  </td>
#  <td><i>1970</i>
#  </td>
#  <td>
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-22"><a href="#cite_note-22">[fp 22]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Albiol, Raul" scope="row"><a href="/wiki/Ra%C3%BAl_Albiol" title="Raúl Albiol">Raúl Albiol</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="500" data-file-width="750" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/9/9a/Flag_of_Spain.svg/23px-Flag_of_Spain.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/9a/Flag_of_Spain.svg/35px-Flag_of_Spain.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/9a/Flag_of_Spain.svg/45px-Flag_of_Spain.svg.png 2x" width="23"/> </span><a href="/wiki/Spain_national_football_team" title="Spain national football team">Spain</a></span>
#  </td>
#  <td style="text-align: center;">1
#  </td>
#  <td><i>2010</i>
#  </td>
#  <td>2014
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-23"><a href="#cite_note-23">[fp 23]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Aldair" scope="row"><a href="/wiki/Aldair" title="Aldair">Aldair</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="504" data-file-width="720" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/0/05/Flag_of_Brazil.svg/22px-Flag_of_Brazil.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/05/Flag_of_Brazil.svg/33px-Flag_of_Brazil.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/05/Flag_of_Brazil.svg/43px-Flag_of_Brazil.svg.png 2x" width="22"/> </span><a href="/wiki/Brazil_national_football_team" title="Brazil national football team">Brazil</a></span>
#  </td>
#  <td style="text-align: center;">1
#  </td>
#  <td><b>1994</b>
#  </td>
#  <td><i>1990</i>, 1998
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-24"><a href="#cite_note-24">[fp 24]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Allemandi, Luigi" scope="row"><a href="/wiki/Luigi_Allemandi" title="Luigi Allemandi">Luigi Allemandi</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="1000" data-file-width="1500" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/78/Flag_of_Italy_%281861%E2%80%931946%29.svg/23px-Flag_of_Italy_%281861%E2%80%931946%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/78/Flag_of_Italy_%281861%E2%80%931946%29.svg/35px-Flag_of_Italy_%281861%E2%80%931946%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/78/Flag_of_Italy_%281861%E2%80%931946%29.svg/45px-Flag_of_Italy_%281861%E2%80%931946%29.svg.png 2x" width="23"/> </span><a href="/wiki/Italy_national_football_team" title="Italy national football team">Italy</a></span>
#  </td>
#  <td style="text-align: center;">1
#  </td>
#  <td><b>1934</b>
#  </td>
#  <td>
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-25"><a href="#cite_note-25">[fp 25]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Almiron, Sergio" scope="row"><a href="/wiki/Sergio_Omar_Almir%C3%B3n" title="Sergio Omar Almirón">Sergio Almirón</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="500" data-file-width="800" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_Argentina.svg/23px-Flag_of_Argentina.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_Argentina.svg/35px-Flag_of_Argentina.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_Argentina.svg/46px-Flag_of_Argentina.svg.png 2x" width="23"/> </span><a href="/wiki/Argentina_national_football_team" title="Argentina national football team">Argentina</a></span>
#  </td>
#  <td style="text-align: center;">1
#  </td>
#  <td><i>1986</i>
#  </td>
#  <td>
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-26"><a href="#cite_note-26">[fp 26]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Alonso, Norberto" scope="row"><a href="/wiki/Norberto_Alonso" title="Norberto Alonso">Norberto Alonso</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="500" data-file-width="800" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_Argentina.svg/23px-Flag_of_Argentina.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_Argentina.svg/35px-Flag_of_Argentina.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_Argentina.svg/46px-Flag_of_Argentina.svg.png 2x" width="23"/> </span><a href="/wiki/Argentina_national_football_team" title="Argentina national football team">Argentina</a></span>
#  </td>
#  <td style="text-align: center;">1
#  </td>
#  <td>1978
#  </td>
#  <td>
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-27"><a href="#cite_note-27">[fp 27]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Alonso, Xabi" scope="row"><a href="/wiki/Xabi_Alonso" title="Xabi Alonso">Xabi Alonso</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="500" data-file-width="750" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/9/9a/Flag_of_Spain.svg/23px-Flag_of_Spain.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/9a/Flag_of_Spain.svg/35px-Flag_of_Spain.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/9a/Flag_of_Spain.svg/45px-Flag_of_Spain.svg.png 2x" width="23"/> </span><a href="/wiki/Spain_national_football_team" title="Spain national football team">Spain</a></span>
#  </td>
#  <td style="text-align: center;">1
#  </td>
#  <td><b>2010</b>
#  </td>
#  <td>2006, 2014
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-28"><a href="#cite_note-28">[fp 28]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Altafini, Jose" scope="row"><a href="/wiki/Jos%C3%A9_Altafini" title="José Altafini">José Altafini</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="504" data-file-width="720" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/92/Flag_of_Brazil_%281889%E2%80%931960%29.svg/22px-Flag_of_Brazil_%281889%E2%80%931960%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/92/Flag_of_Brazil_%281889%E2%80%931960%29.svg/33px-Flag_of_Brazil_%281889%E2%80%931960%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/92/Flag_of_Brazil_%281889%E2%80%931960%29.svg/43px-Flag_of_Brazil_%281889%E2%80%931960%29.svg.png 2x" width="22"/> </span><a href="/wiki/Brazil_national_football_team" title="Brazil national football team">Brazil</a></span>
#  </td>
#  <td style="text-align: center;">1
#  </td>
#  <td>1958
#  </td>
#  <td>1962 <small><a href="/wiki/Italy_national_football_team" title="Italy national football team">ITA</a></small><sup class="reference" id="cite_ref-different_teams_29-0"><a href="#cite_note-different_teams-29">[n 1]</a></sup>
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-30"><a href="#cite_note-30">[fp 29]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Altair" scope="row"><a href="/wiki/Altair_Gomes_de_Figueiredo" title="Altair Gomes de Figueiredo">Altair</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="504" data-file-width="720" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/22px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/33px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/43px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 2x" width="22"/> </span><a href="/wiki/Brazil_national_football_team" title="Brazil national football team">Brazil</a></span>
#  </td>
#  <td style="text-align: center;">1
#  </td>
#  <td><i>1962</i>
#  </td>
#  <td>1966
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-31"><a href="#cite_note-31">[fp 30]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Altobelli, Alessandro" scope="row"><a href="/wiki/Alessandro_Altobelli" title="Alessandro Altobelli">Alessandro Altobelli</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="1000" data-file-width="1500" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/23px-Flag_of_Italy.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/35px-Flag_of_Italy.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/45px-Flag_of_Italy.svg.png 2x" width="23"/> </span><a href="/wiki/Italy_national_football_team" title="Italy national football team">Italy</a></span>
#  </td>
#  <td style="text-align: center;">1
#  </td>
#  <td><b>1982</b>
#  </td>
#  <td>1986
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-32"><a href="#cite_note-32">[fp 31]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Amarildo" scope="row"><a href="/wiki/Amarildo_Tavares_da_Silveira" title="Amarildo Tavares da Silveira">Amarildo</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="504" data-file-width="720" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/22px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/33px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/49/Flag_of_Brazil_%281960%E2%80%931968%29.svg/43px-Flag_of_Brazil_%281960%E2%80%931968%29.svg.png 2x" width="22"/> </span><a href="/wiki/Brazil_national_football_team" title="Brazil national football team">Brazil</a></span>
#  </td>
#  <td style="text-align: center;">1
#  </td>
#  <td><i>1962</i>
#  </td>
#  <td>
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-33"><a href="#cite_note-33">[fp 32]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Amelia, Marco" scope="row"><a href="/wiki/Marco_Amelia" title="Marco Amelia">Marco Amelia</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="1000" data-file-width="1500" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/41/Flag_of_Italy_%282003%E2%80%932006%29.svg/23px-Flag_of_Italy_%282003%E2%80%932006%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/41/Flag_of_Italy_%282003%E2%80%932006%29.svg/35px-Flag_of_Italy_%282003%E2%80%932006%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/41/Flag_of_Italy_%282003%E2%80%932006%29.svg/45px-Flag_of_Italy_%282003%E2%80%932006%29.svg.png 2x" width="23"/> </span><a href="/wiki/Italy_national_football_team" title="Italy national football team">Italy</a></span>
#  </td>
#  <td style="text-align: center;">1
#  </td>
#  <td><i>2006</i>
#  </td>
#  <td>
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-34"><a href="#cite_note-34">[fp 33]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Anderson Polga" scope="row"><a href="/wiki/%C3%82nderson_Polga" title="Ânderson Polga">Ânderson Polga</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="504" data-file-width="720" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/0/05/Flag_of_Brazil.svg/22px-Flag_of_Brazil.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/05/Flag_of_Brazil.svg/33px-Flag_of_Brazil.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/05/Flag_of_Brazil.svg/43px-Flag_of_Brazil.svg.png 2x" width="22"/> </span><a href="/wiki/Brazil_national_football_team" title="Brazil national football team">Brazil</a></span>
#  </td>
#  <td style="text-align: center;">1
#  </td>
#  <td>2002
#  </td>
#  <td>
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-35"><a href="#cite_note-35">[fp 34]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Andrade, Jose" scope="row"><a href="/wiki/Jos%C3%A9_Leandro_Andrade" title="José Leandro Andrade">José Andrade</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="630" data-file-width="945" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Flag_of_Uruguay.svg/23px-Flag_of_Uruguay.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Flag_of_Uruguay.svg/35px-Flag_of_Uruguay.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Flag_of_Uruguay.svg/45px-Flag_of_Uruguay.svg.png 2x" width="23"/> </span><a href="/wiki/Uruguay_national_football_team" title="Uruguay national football team">Uruguay</a></span>
#  </td>
#  <td style="text-align: center;">1
#  </td>
#  <td><b>1930</b>
#  </td>
#  <td>
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-36"><a href="#cite_note-36">[fp 35]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Andreolo, Michele" scope="row"><a href="/wiki/Michele_Andreolo" title="Michele Andreolo">Michele Andreolo</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="1000" data-file-width="1500" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/78/Flag_of_Italy_%281861%E2%80%931946%29.svg/23px-Flag_of_Italy_%281861%E2%80%931946%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/78/Flag_of_Italy_%281861%E2%80%931946%29.svg/35px-Flag_of_Italy_%281861%E2%80%931946%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/78/Flag_of_Italy_%281861%E2%80%931946%29.svg/45px-Flag_of_Italy_%281861%E2%80%931946%29.svg.png 2x" width="23"/> </span><a href="/wiki/Italy_national_football_team" title="Italy national football team">Italy</a></span>
#  </td>
#  <td style="text-align: center;">1
#  </td>
#  <td><b>1938</b>
#  </td>
#  <td>
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-37"><a href="#cite_note-37">[fp 36]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Anselmo, Peregrino" scope="row"><a href="/wiki/Peregrino_Anselmo" title="Peregrino Anselmo">Peregrino Anselmo</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="630" data-file-width="945" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Flag_of_Uruguay.svg/23px-Flag_of_Uruguay.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Flag_of_Uruguay.svg/35px-Flag_of_Uruguay.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Flag_of_Uruguay.svg/45px-Flag_of_Uruguay.svg.png 2x" width="23"/> </span><a href="/wiki/Uruguay_national_football_team" title="Uruguay national football team">Uruguay</a></span>
#  </td>
#  <td style="text-align: center;">1
#  </td>
#  <td>1930
#  </td>
#  <td>
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-38"><a href="#cite_note-38">[fp 37]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Antognoni, Giancarlo" scope="row"><a href="/wiki/Giancarlo_Antognoni" title="Giancarlo Antognoni">Giancarlo Antognoni</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="1000" data-file-width="1500" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/23px-Flag_of_Italy.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/35px-Flag_of_Italy.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/45px-Flag_of_Italy.svg.png 2x" width="23"/> </span><a href="/wiki/Italy_national_football_team" title="Italy national football team">Italy</a></span>
#  </td>
#  <td style="text-align: center;">1
#  </td>
#  <td>1982
#  </td>
#  <td>1978
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-39"><a href="#cite_note-39">[fp 38]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Arbeloa, Alvaro" scope="row"><a href="/wiki/%C3%81lvaro_Arbeloa" title="Álvaro Arbeloa">Álvaro Arbeloa</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="500" data-file-width="750" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/9/9a/Flag_of_Spain.svg/23px-Flag_of_Spain.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/9a/Flag_of_Spain.svg/35px-Flag_of_Spain.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/9a/Flag_of_Spain.svg/45px-Flag_of_Spain.svg.png 2x" width="23"/> </span><a href="/wiki/Spain_national_football_team" title="Spain national football team">Spain</a></span>
#  </td>
#  <td style="text-align: center;">1
#  </td>
#  <td>2010
#  </td>
#  <td>
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-40"><a href="#cite_note-40">[fp 39]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Arcari, Pietro" scope="row"><a href="/wiki/Pietro_Arcari" title="Pietro Arcari">Pietro Arcari</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="1000" data-file-width="1500" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/78/Flag_of_Italy_%281861%E2%80%931946%29.svg/23px-Flag_of_Italy_%281861%E2%80%931946%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/78/Flag_of_Italy_%281861%E2%80%931946%29.svg/35px-Flag_of_Italy_%281861%E2%80%931946%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/78/Flag_of_Italy_%281861%E2%80%931946%29.svg/45px-Flag_of_Italy_%281861%E2%80%931946%29.svg.png 2x" width="23"/> </span><a href="/wiki/Italy_national_football_team" title="Italy national football team">Italy</a></span>
#  </td>
#  <td style="text-align: center;">1
#  </td>
#  <td><i>1934</i>
#  </td>
#  <td>
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-41"><a href="#cite_note-41">[fp 40]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Ardiles, Osvaldo" scope="row"><a href="/wiki/Osvaldo_Ardiles" title="Osvaldo Ardiles">Osvaldo Ardiles</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="500" data-file-width="800" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_Argentina.svg/23px-Flag_of_Argentina.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_Argentina.svg/35px-Flag_of_Argentina.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_Argentina.svg/46px-Flag_of_Argentina.svg.png 2x" width="23"/> </span><a href="/wiki/Argentina_national_football_team" title="Argentina national football team">Argentina</a></span>
#  </td>
#  <td style="text-align: center;">1
#  </td>
#  <td><b>1978</b>
#  </td>
#  <td>1982
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-42"><a href="#cite_note-42">[fp 41]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Areola, Alphonse" scope="row"><a href="/wiki/Alphonse_Areola" title="Alphonse Areola">Alphonse Areola</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/c/c3/Flag_of_France.svg/23px-Flag_of_France.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/c/c3/Flag_of_France.svg/35px-Flag_of_France.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/c/c3/Flag_of_France.svg/45px-Flag_of_France.svg.png 2x" width="23"/> </span><a href="/wiki/France_national_football_team" title="France national football team">France</a></span>
#  </td>
#  <td style="text-align: center;">1
#  </td>
#  <td><i>2018</i>
#  </td>
#  <td>
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-43"><a href="#cite_note-43">[fp 42]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Armfield, Jimmy" scope="row"><a href="/wiki/Jimmy_Armfield" title="Jimmy Armfield">Jimmy Armfield</a>
#  </th>
#  <td><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="480" data-file-width="800" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/en/thumb/b/be/Flag_of_England.svg/23px-Flag_of_England.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/b/be/Flag_of_England.svg/35px-Flag_of_England.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/b/be/Flag_of_England.svg/46px-Flag_of_England.svg.png 2x" width="23"/> </span><a href="/wiki/England_national_football_team" title="England national football team">England</a></span>
#  </td>
#  <td style="text-align: center;">1
#  </td>
#  <td><i>1966</i>
#  </td>
#  <td>1962
#  </td>
#  <td>
#  </td>
#  <td style="text-align: center;"><sup class="reference" id="cite_ref-44"><a href="#cite_note-44">[fp 43]</a></sup>
#  </td></tr>
#  <tr>
#  <th data-sort-value="Augenthaler, Klaus" scope="row"><a href="/wiki/Klaus_Augenthaler" title="Klaus Augenthaler">Klaus Augenthaler</a>
#  </th>
#  <td data-sort-value="Germany, West"><span style="white-space:nowrap"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="1000" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/en/thumb/b/ba/Flag_of_Germany.svg/23px-Flag_of_Germany.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/b/ba/Flag_of_Germany.svg/35px-Flag_of_Germany.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/b/ba/Flag_of_Germany.svg/46px-Flag_of_Germany.svg.png 2x" width="23"/> </span><a href="/wiki/Germany_national_football_team" title="Germany national football team">West Germany</a></span>
#  </td>
# ...
#  <li><a href="/wiki/1962_FIFA_World_Cup_qualification" title="1962 FIFA World Cup qualification">1962</a></li>
#  <li><a href="/wiki/1966_FIFA_World_Cup_qualification" title="1966 FIFA World Cup qualification">1966</a></li>
#  <li><a href="/wiki/1970_FIFA_World_Cup_qualification" title="1970 FIFA World Cup qualification">1970</a></li>
#  <li><a href="/wiki/1974_FIFA_World_Cup_qualification" title="1974 FIFA World Cup qualification">1974</a></li>
#  <li><a href="/wiki/1978_FIFA_World_Cup_qualification" title="1978 FIFA World Cup qualification">1978</a></li>
#  <li><a href="/wiki/1982_FIFA_World_Cup_qualification" title="1982 FIFA World Cup qualification">1982</a></li>
#  <li><a href="/wiki/1986_FIFA_World_Cup_qualification" title="1986 FIFA World Cup qualification">1986</a></li>
#  <li><a href="/wiki/1990_FIFA_World_Cup_qualification" title="1990 FIFA World Cup qualification">1990</a></li>
#  <li><a href="/wiki/1994_FIFA_World_Cup_qualification" title="1994 FIFA World Cup qualification">1994</a></li>
#  <li><a href="/wiki/1998_FIFA_World_Cup_qualification" title="1998 FIFA World Cup qualification">1998</a></li>
#  <li><a href="/wiki/2002_FIFA_World_Cup_qualification" title="2002 FIFA World Cup qualification">2002</a></li>
#  <li><a href="/wiki/2006_FIFA_World_Cup_qualification" title="2006 FIFA World Cup qualification">2006</a></li>
#  <li><a href="/wiki/2010_FIFA_World_Cup_qualification" title="2010 FIFA World Cup qualification">2010</a></li>
#  <li><a href="/wiki/2014_FIFA_World_Cup_qualification" title="2014 FIFA World Cup qualification">2014</a></li>
#  <li><a href="/wiki/2018_FIFA_World_Cup_qualification" title="2018 FIFA World Cup qualification">2018</a></li>
#  <li><a href="/wiki/2022_FIFA_World_Cup_qualification" title="2022 FIFA World Cup qualification">2022</a></li></ul>
#  </div></td></tr><tr><th class="navbox-group" scope="row" style="background:gold;;width:1%"><a href="/wiki/List_of_FIFA_World_Cup_finals" title="List of FIFA World Cup finals">Finals</a></th><td class="navbox-list navbox-odd hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px"><div style="padding:0em 0.25em">
#  <ul><li><a href="/wiki/1930_FIFA_World_Cup_Final" title="1930 FIFA World Cup Final">1930</a></li>
#  <li><a href="/wiki/1934_FIFA_World_Cup_Final" title="1934 FIFA World Cup Final">1934</a></li>
#  <li><a href="/wiki/1938_FIFA_World_Cup_Final" title="1938 FIFA World Cup Final">1938</a></li>
#  <li><i><a href="/wiki/Uruguay_v_Brazil_(1950_FIFA_World_Cup)" title="Uruguay v Brazil (1950 FIFA World Cup)">1950</a></i></li>
#  <li><a href="/wiki/1954_FIFA_World_Cup_Final" title="1954 FIFA World Cup Final">1954</a></li>
#  <li><a href="/wiki/1958_FIFA_World_Cup_Final" title="1958 FIFA World Cup Final">1958</a></li>
#  <li><a href="/wiki/1962_FIFA_World_Cup_Final" title="1962 FIFA World Cup Final">1962</a></li>
#  <li><a href="/wiki/1966_FIFA_World_Cup_Final" title="1966 FIFA World Cup Final">1966</a></li>
#  <li><a href="/wiki/1970_FIFA_World_Cup_Final" title="1970 FIFA World Cup Final">1970</a></li>
#  <li><a href="/wiki/1974_FIFA_World_Cup_Final" title="1974 FIFA World Cup Final">1974</a></li>
#  <li><a href="/wiki/1978_FIFA_World_Cup_Final" title="1978 FIFA World Cup Final">1978</a></li>
#  <li><a href="/wiki/1982_FIFA_World_Cup_Final" title="1982 FIFA World Cup Final">1982</a></li>
#  <li><a href="/wiki/1986_FIFA_World_Cup_Final" title="1986 FIFA World Cup Final">1986</a></li>
#  <li><a href="/wiki/1990_FIFA_World_Cup_Final" title="1990 FIFA World Cup Final">1990</a></li>
#  <li><a href="/wiki/1994_FIFA_World_Cup_Final" title="1994 FIFA World Cup Final">1994</a></li>
#  <li><a href="/wiki/1998_FIFA_World_Cup_Final" title="1998 FIFA World Cup Final">1998</a></li>
#  <li><a href="/wiki/2002_FIFA_World_Cup_Final" title="2002 FIFA World Cup Final">2002</a></li>
#  <li><a href="/wiki/2006_FIFA_World_Cup_Final" title="2006 FIFA World Cup Final">2006</a></li>
#  <li><a href="/wiki/2010_FIFA_World_Cup_Final" title="2010 FIFA World Cup Final">2010</a></li>
#  <li><a href="/wiki/2014_FIFA_World_Cup_Final" title="2014 FIFA World Cup Final">2014</a></li>
#  <li><a href="/wiki/2018_FIFA_World_Cup_Final" title="2018 FIFA World Cup Final">2018</a></li></ul>
#  </div></td></tr><tr><th class="navbox-group" scope="row" style="background:gold;;width:1%">Squads</th><td class="navbox-list navbox-even hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px"><div style="padding:0em 0.25em">
#  <ul><li><a href="/wiki/1930_FIFA_World_Cup_squads" title="1930 FIFA World Cup squads">1930</a></li>
#  <li><a href="/wiki/1934_FIFA_World_Cup_squads" title="1934 FIFA World Cup squads">1934</a></li>
#  <li><a href="/wiki/1938_FIFA_World_Cup_squads" title="1938 FIFA World Cup squads">1938</a></li>
#  <li><a href="/wiki/1950_FIFA_World_Cup_squads" title="1950 FIFA World Cup squads">1950</a></li>
#  <li><a href="/wiki/1954_FIFA_World_Cup_squads" title="1954 FIFA World Cup squads">1954</a></li>
#  <li><a href="/wiki/1958_FIFA_World_Cup_squads" title="1958 FIFA World Cup squads">1958</a></li>
#  <li><a href="/wiki/1962_FIFA_World_Cup_squads" title="1962 FIFA World Cup squads">1962</a></li>
#  <li><a href="/wiki/1966_FIFA_World_Cup_squads" title="1966 FIFA World Cup squads">1966</a></li>
#  <li><a href="/wiki/1970_FIFA_World_Cup_squads" title="1970 FIFA World Cup squads">1970</a></li>
#  <li><a href="/wiki/1974_FIFA_World_Cup_squads" title="1974 FIFA World Cup squads">1974</a></li>
#  <li><a href="/wiki/1978_FIFA_World_Cup_squads" title="1978 FIFA World Cup squads">1978</a></li>
#  <li><a href="/wiki/1982_FIFA_World_Cup_squads" title="1982 FIFA World Cup squads">1982</a></li>
#  <li><a href="/wiki/1986_FIFA_World_Cup_squads" title="1986 FIFA World Cup squads">1986</a></li>
#  <li><a href="/wiki/1990_FIFA_World_Cup_squads" title="1990 FIFA World Cup squads">1990</a></li>
#  <li><a href="/wiki/1994_FIFA_World_Cup_squads" title="1994 FIFA World Cup squads">1994</a></li>
#  <li><a href="/wiki/1998_FIFA_World_Cup_squads" title="1998 FIFA World Cup squads">1998</a></li>
#  <li><a href="/wiki/2002_FIFA_World_Cup_squads" title="2002 FIFA World Cup squads">2002</a></li>
#  <li><a href="/wiki/2006_FIFA_World_Cup_squads" title="2006 FIFA World Cup squads">2006</a></li>
#  <li><a href="/wiki/2010_FIFA_World_Cup_squads" title="2010 FIFA World Cup squads">2010</a></li>
#  <li><a href="/wiki/2014_FIFA_World_Cup_squads" title="2014 FIFA World Cup squads">2014</a></li>
#  <li><a href="/wiki/2018_FIFA_World_Cup_squads" title="2018 FIFA World Cup squads">2018</a></li></ul>
#  </div></td></tr><tr><th class="navbox-group" scope="row" style="background:gold;;width:1%"><a href="/wiki/FIFA_World_Cup_final_draw" title="FIFA World Cup final draw">Final draw</a></th><td class="navbox-list navbox-odd hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px"><div style="padding:0em 0.25em">
#  <ul><li><a href="/wiki/1998_FIFA_World_Cup_seeding" title="1998 FIFA World Cup seeding">1998</a></li>
#  <li><a href="/wiki/2002_FIFA_World_Cup_seeding" title="2002 FIFA World Cup seeding">2002</a></li>
#  <li><a href="/wiki/2006_FIFA_World_Cup_seeding" title="2006 FIFA World Cup seeding">2006</a></li>
#  <li><a href="/wiki/2010_FIFA_World_Cup_seeding" title="2010 FIFA World Cup seeding">2010</a></li>
#  <li><a href="/wiki/2014_FIFA_World_Cup_seeding" title="2014 FIFA World Cup seeding">2014</a></li>
#  <li><a href="/wiki/2018_FIFA_World_Cup_seeding" title="2018 FIFA World Cup seeding">2018</a></li></ul>
#  </div></td></tr><tr><th class="navbox-group" scope="row" style="background:gold;;width:1%"><a href="/wiki/List_of_FIFA_World_Cup_broadcasters" title="List of FIFA World Cup broadcasters">Broadcasters</a></th><td class="navbox-list navbox-even hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px"><div style="padding:0em 0.25em">
#  <ul><li><a href="/wiki/1998_FIFA_World_Cup_broadcasting_rights" title="1998 FIFA World Cup broadcasting rights">1998</a></li>
#  <li><a href="/wiki/2002_FIFA_World_Cup_broadcasting_rights" title="2002 FIFA World Cup broadcasting rights">2002</a></li>
#  <li><a href="/wiki/2006_FIFA_World_Cup_broadcasting_rights" title="2006 FIFA World Cup broadcasting rights">2006</a></li>
#  <li><a href="/wiki/2010_FIFA_World_Cup_broadcasting_rights" title="2010 FIFA World Cup broadcasting rights">2010</a></li>
#  <li><a href="/wiki/2014_FIFA_World_Cup_broadcasting_rights" title="2014 FIFA World Cup broadcasting rights">2014</a></li>
#  <li><a href="/wiki/2018_FIFA_World_Cup_broadcasting_rights" title="2018 FIFA World Cup broadcasting rights">2018</a></li></ul>
#  </div></td></tr><tr><th class="navbox-group" scope="row" style="background:gold;;width:1%"><a href="/wiki/FIFA_World_Cup_hosts" title="FIFA World Cup hosts">Bids</a></th><td class="navbox-list navbox-odd hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px"><div style="padding:0em 0.25em">
#  <ul><li><a href="/wiki/2014_FIFA_World_Cup_bids" title="2014 FIFA World Cup bids">2014</a></li>
#  <li><a href="/wiki/2018_and_2022_FIFA_World_Cup_bids" title="2018 and 2022 FIFA World Cup bids">2018 and 2022</a></li>
#  <li><a href="/wiki/2026_FIFA_World_Cup_bids" title="2026 FIFA World Cup bids">2026</a></li>
#  <li><i><a class="mw-redirect" href="/wiki/2030_FIFA_World_Cup_bids" title="2030 FIFA World Cup bids">2030</a></i></li></ul>
#  </div></td></tr><tr><th class="navbox-group" scope="row" style="background:gold;;width:1%">Statistics</th><td class="navbox-list navbox-even hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px"><div style="padding:0em 0.25em">
#  <ul><li><a href="/wiki/2002_FIFA_World_Cup_statistics" title="2002 FIFA World Cup statistics">2002</a></li>
#  <li><a href="/wiki/2006_FIFA_World_Cup_statistics" title="2006 FIFA World Cup statistics">2006</a></li>
#  <li><a href="/wiki/2010_FIFA_World_Cup_statistics" title="2010 FIFA World Cup statistics">2010</a></li>
#  <li><a href="/wiki/2014_FIFA_World_Cup_statistics" title="2014 FIFA World Cup statistics">2014</a></li>
#  <li><a href="/wiki/2018_FIFA_World_Cup_statistics" title="2018 FIFA World Cup statistics">2018</a></li></ul>
#  </div></td></tr><tr><th class="navbox-group" scope="row" style="background:gold;;width:1%"><a href="/wiki/National_team_appearances_in_the_FIFA_World_Cup" title="National team appearances in the FIFA World Cup">Team appearances</a></th><td class="navbox-list navbox-odd hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px"><div style="padding:0em 0.25em">
#  <ul><li><a href="/wiki/Asian_nations_at_the_FIFA_World_Cup" title="Asian nations at the FIFA World Cup">AFC</a></li>
#  <li><a href="/wiki/African_nations_at_the_FIFA_World_Cup" title="African nations at the FIFA World Cup">CAF</a></li>
#  <li><a href="/wiki/North,_Central_American_and_Caribbean_nations_at_the_FIFA_World_Cup" title="North, Central American and Caribbean nations at the FIFA World Cup">CONCACAF</a></li>
#  <li><a href="/wiki/South_American_nations_at_the_FIFA_World_Cup" title="South American nations at the FIFA World Cup">CONMEBOL</a></li>
#  <li><a href="/wiki/Oceanian_nations_at_the_FIFA_World_Cup" title="Oceanian nations at the FIFA World Cup">OFC</a></li>
#  <li><a href="/wiki/European_nations_at_the_FIFA_World_Cup" title="European nations at the FIFA World Cup">UEFA</a></li></ul>
#  </div></td></tr><tr><th class="navbox-group" scope="row" style="background:gold;;width:1%"><a href="/wiki/List_of_FIFA_World_Cup_records_and_statistics" title="List of FIFA World Cup records and statistics">Overall records</a></th><td class="navbox-list navbox-even hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px"><div style="padding:0em 0.25em">
#  <ul><li><a href="/wiki/All-time_table_of_the_FIFA_World_Cup" title="All-time table of the FIFA World Cup">All-time table</a></li>
#  <li><a href="/wiki/List_of_FIFA_World_Cup_goalscorers" title="List of FIFA World Cup goalscorers">Goalscorers</a>
#  <ul><li><a href="/wiki/FIFA_World_Cup_top_goalscorers" title="FIFA World Cup top goalscorers">top goalscorers</a></li>
#  <li><a href="/wiki/List_of_FIFA_World_Cup_final_goalscorers" title="List of FIFA World Cup final goalscorers">finals goalscorers</a></li>
#  <li><a href="/wiki/List_of_FIFA_World_Cup_hat-tricks" title="List of FIFA World Cup hat-tricks">hat-tricks</a></li>
#  <li><a href="/wiki/List_of_FIFA_World_Cup_own_goals" title="List of FIFA World Cup own goals">own goals</a></li></ul></li>
#  <li><a href="/wiki/List_of_managers_at_the_FIFA_World_Cup" title="List of managers at the FIFA World Cup">Managers</a></li>
#  <li><a href="/wiki/List_of_FIFA_World_Cup_opening_matches" title="List of FIFA World Cup opening matches">Opening matches</a></li>
#  <li><a href="/wiki/List_of_FIFA_World_Cup_penalty_shoot-outs" title="List of FIFA World Cup penalty shoot-outs">Penalty shoot-outs</a></li>
#  <li><a href="/wiki/List_of_players_who_have_appeared_in_multiple_FIFA_World_Cups" title="List of players who have appeared in multiple FIFA World Cups">Player appearances</a></li>
#  <li><a href="/wiki/List_of_FIFA_World_Cup_red_cards" title="List of FIFA World Cup red cards">Red cards</a></li>
#  <li><a href="/wiki/FIFA_World_Cup_referees" title="FIFA World Cup referees">Referees</a></li>
#  <li><a class="mw-selflink selflink">Winning players</a></li>
#  <li><a href="/wiki/List_of_FIFA_World_Cup_winning_managers" title="List of FIFA World Cup winning managers">Winning managers</a></li></ul>
#  </div></td></tr><tr><th class="navbox-group" scope="row" style="background:gold;;width:1%">Miscellaneous</th><td class="navbox-list navbox-odd hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px"><div style="padding:0em 0.25em">
#  <ul><li><a href="/wiki/FIFA_World_Cup_awards" title="FIFA World Cup awards">Awards</a></li>
#  <li><a href="/wiki/List_of_FIFA_World_Cup_official_match_balls" title="List of FIFA World Cup official match balls">Balls</a></li>
#  <li><a href="/wiki/Category:FIFA_World_Cup_controversies" title="Category:FIFA World Cup controversies">Controversies</a></li>
#  <li><a href="/wiki/Economics_of_the_FIFA_World_Cup" title="Economics of the FIFA World Cup">Economics</a></li>
#  <li><a href="/wiki/FIFA_Fan_Fest" title="FIFA Fan Fest">Fan fest</a></li>
#  <li><a href="/wiki/FIFA_World_Cup_official_films" title="FIFA World Cup official films">Films</a></li>
#  <li><a href="/wiki/History_of_the_FIFA_World_Cup" title="History of the FIFA World Cup">History</a></li>
#  <li><a href="/wiki/FIFA_World_Cup_official_mascots" title="FIFA World Cup official mascots">Mascots</a></li>
#  <li><a href="/wiki/List_of_FIFA_World_Cup_anthems_and_songs" title="List of FIFA World Cup anthems and songs">Music</a></li>
#  <li><a href="/wiki/Category:FIFA_World_Cup_matches" title="Category:FIFA World Cup matches">Notable matches</a>
#  <ul><li><a href="/wiki/Category:FIFA_World_Cup_qualification_matches" title="Category:FIFA World Cup qualification matches">qualifying</a></li></ul></li>
#  <li><a href="/wiki/FIFA_World_Cup_Organisers" title="FIFA World Cup Organisers">Organisers</a></li>
#  <li><a class="mw-redirect" href="/wiki/FIFA_World_Cup_stadiums" title="FIFA World Cup stadiums">Stadiums</a>
#  <ul><li><a href="/wiki/List_of_FIFA_World_Cup_final_stadiums" title="List of FIFA World Cup final stadiums">Final stadiums</a></li></ul></li>
#  <li><a href="/wiki/FIFA_World_Cup_Trophy" title="FIFA World Cup Trophy">Trophy</a></li>
#  <li><a href="/wiki/FIFA_World_Cup_video_games" title="FIFA World Cup video games">Video games</a></li>
#  <li><a href="/wiki/1980_Mundialito" title="1980 Mundialito">World Champions Cup</a></li></ul>
#  </div></td></tr><tr><td class="navbox-abovebelow" colspan="2" style="background:gold;"><div>Notes: There was no qualification for the 1930 World Cup as places were given by invitation only. In 1950, there was no final; the article is about the decisive match of the final group stage.</div></td></tr></tbody></table>]

# %% [markdown]
# Now we have a list of tables in the web page. Let's scrape the first table - the nations that won the word cup.

# %%
df = pd.DataFrame({"year": [], "Team": []})
row = []
df = []
for i,entry in enumerate(tables[0].find_all("td")):
    row.append(entry.text)
    if (i+1)%3 == 0:
        df.append(row)
        row = []

df = pd.DataFrame(df, columns = ["team", "n_titles", "years"])
df
# Out:
#                    team n_titles               years
# 0              Brazil\n      3\n  1958, 1962, 1970\n
# 1                1966\n       \n            [fp 1]\n
# 2              Brazil\n      2\n        1958, 1962\n
# 3                1966\n       \n            [fp 2]\n
# 4              Brazil\n      2\n        1994, 2002\n
# ..                  ...      ...                 ...
# 885                  \n       \n          [fp 443]\n
# 886            Brazil\n      1\n              1994\n
# 887                  \n       \n          [fp 444]\n
# 888             Italy\n      1\n              1982\n
# 889  1970, 1974, 1978\n       \n          [fp 445]\n
#
# [890 rows x 3 columns]

# %% [markdown]
# How cool is that? Of course we need some data cleaning.

# %%
df = df.replace("\n","", regex=True)
df = df.replace("\[[A-Za-z0-9 ]*\]","", regex=True)
df
# Out:
#                  team n_titles             years
# 0              Brazil        3  1958, 1962, 1970
# 1                1966
# 2              Brazil        2        1958, 1962
# 3                1966
# 4              Brazil        2        1994, 2002
# ..                ...      ...               ...
# 885
# 886            Brazil        1              1994
# 887
# 888             Italy        1              1982
# 889  1970, 1974, 1978
#
# [890 rows x 3 columns]

# %% [markdown]
# As we can see, Brazil has the highest number of World Cup titles in the world. YEAH, yeah! Don't get upset, Canada would crush us in Hockey (I don't know if we even have a team!). We could keep manipulating this dataframe, but let's keep our focus on scrapping data. Let's get the names of the players that won the world cup, which are present in the second column in the first table of the wiki-page.

# %%
#tables[0]

# %%
players = []
teams = []
for entry in tables[0].find_all("th"):
    if entry.has_attr("data-sort-value"): # Note the function I'm using here: has_attr(). Inspect the page on your browser to see why
        players.append(entry.text)
        
players = pd.Series(players, name='Player', dtype='object').str.replace("\n","")
players
# Out:
# 0                   Pelé
# 1                Bellini
# 2                   Cafu
# 3               Castilho
# 4                   Didi
#              ...
# 440                Zetti
# 441      Zinedine Zidane
# 442    Ron-Robert Zieler
# 443                Zinho
# 444            Dino Zoff
# Name: Player, Length: 445, dtype: object

# %% [markdown]
# But why are we doing this? Isn't easier to just copy the table directly from the page? Well, if you have only one table, it would be. But say that you want the date of birth of all these players that won the word cup. This information is not present in the table, so we need to gather from somewhere else. However, the table does provide us with the link for the wiki-page of each one of those players. We just need to go there and gather that information. Doing it manually for the 510 players would be annoying, right?
#
# Well, this could take a while since there are 510 players, but let's do for the first 25 players just so we get a taste.

# %%
url = "https://en.wikipedia.org"
bday = []
for name in players[0:25]:
    player_pg = requests.get(url+tables[0].find("a", text=name)["href"])
    print(url+tables[0].find("a", text=name)["href"])
    player_pg = BeautifulSoup(player_pg.text)
    try:
        print(player_pg.find("span", {"class":"bday"}).text)
        bday.append(player_pg.find("span", {"class":"bday"}).text)
    except:
        bday.append(player_pg.find("th", text="Date of birth").next_sibling.text)
    time.sleep(.5)

print("Finished!")
# Out:
# https://en.wikipedia.org/wiki/Pel%C3%A9
# 1940-10-23
# https://en.wikipedia.org/wiki/Hilderaldo_Bellini
# 1930-06-07
# https://en.wikipedia.org/wiki/Cafu
# 1970-06-07
# https://en.wikipedia.org/wiki/Carlos_Jos%C3%A9_Castilho
# 1927-11-27
# https://en.wikipedia.org/wiki/Didi_(footballer,_born_1928)
# 1928-10-08
# https://en.wikipedia.org/wiki/Djalma_Santos
# 1929-02-27
# https://en.wikipedia.org/wiki/Giovanni_Ferrari
# 1907-12-06
# https://en.wikipedia.org/wiki/Garrincha
# 1933-10-28
# https://en.wikipedia.org/wiki/Gylmar_dos_Santos_Neves
# 1930-08-22
# https://en.wikipedia.org/wiki/Guido_Masetti
# 1907-11-22
# https://en.wikipedia.org/wiki/Mauro_Ramos
# 1930-08-30
# https://en.wikipedia.org/wiki/Giuseppe_Meazza
# 1910-08-23
# https://en.wikipedia.org/wiki/Eraldo_Monzeglio
# 1906-06-05
# https://en.wikipedia.org/wiki/N%C3%ADlton_Santos
# 1925-05-16
# https://en.wikipedia.org/wiki/Daniel_Passarella
# 1953-05-25
# https://en.wikipedia.org/wiki/Pepe_(footballer,_born_1935)
# 1935-02-25
# https://en.wikipedia.org/wiki/Ronaldo_(Brazilian_footballer)
# 1976-09-18
# https://en.wikipedia.org/wiki/Vav%C3%A1
# 1934-11-12
# https://en.wikipedia.org/wiki/M%C3%A1rio_Zagallo
# 1931-08-09
# https://en.wikipedia.org/wiki/Zito_(footballer)
# https://en.wikipedia.org/wiki/Z%C3%B3zimo
# 1932-06-19
# https://en.wikipedia.org/wiki/Ado_(footballer)
# 1944-07-04
# https://en.wikipedia.org/wiki/Ra%C3%BAl_Albiol
# 1985-09-04
# https://en.wikipedia.org/wiki/Aldair
# 1965-11-30
# https://en.wikipedia.org/wiki/Luigi_Allemandi
# 1903-11-08
# Finished!

# %% [markdown]
# Why did I add a `time.sleep` in the code? It is to give some time to the server. We want to be polite and not overload the server with too many requests in a short time. You need to be aware of that. If you are dealing with a small server, you could cause real problems. Besides, you could get blocked. Wikipedia is a very big server, and we aren't requesting that many pages, so we should be fine here. But always keep this in mind.
#
# Now, let's check the date of birth of the first 25 players. Please note that the previous block of code must successfully finish running first for the birthday table to display properly.

# %%
players_won_world_cup = pd.concat([players[0:25],pd.Series(bday, name="bday", dtype = 'object')], axis=1)
players_won_world_cup
# Out:
#                Player             bday
# 0                Pelé       1940-10-23
# 1             Bellini       1930-06-07
# 2                Cafu       1970-06-07
# 3            Castilho       1927-11-27
# 4                Didi       1928-10-08
# 5       Djalma Santos       1929-02-27
# 6    Giovanni Ferrari       1907-12-06
# 7           Garrincha       1933-10-28
# 8              Gilmar       1930-08-22
# 9       Guido Masetti       1907-11-22
# 10              Mauro       1930-08-30
# 11    Giuseppe Meazza       1910-08-23
# 12   Eraldo Monzeglio       1906-06-05
# 13      Nílton Santos       1925-05-16
# 14  Daniel Passarella       1953-05-25
# 15               Pepe       1935-02-25
# 16            Ronaldo       1976-09-18
# 17               Vavá       1934-11-12
# 18      Mário Zagallo       1931-08-09
# 19               Zito  \n8 August 1932
# 20             Zózimo       1932-06-19
# 21                Ado       1944-07-04
# 22        Raúl Albiol       1985-09-04
# 23             Aldair       1965-11-30
# 24    Luigi Allemandi       1903-11-08

# %% [markdown]
# Cool, right?
# One last thing before you start: your browser's developer tools is your ally in navigating a website structure.
#
# Finally, let's begin your assigment.

# %% [markdown]
# # Exercise 1: Creating a prerequisite diagram
#
# Below is a prerequisite chart for the 25 MDS courses:
#
# ![](MDS-prereq2.png)
#
# In this assignment, you will reproduce this graph, or something very similar, by scraping the prerequisite info from https://courses.students.ubc.ca/cs/courseschedule?tname=subj-department&campuscd=UBCO&dept=DATA&pname=subjarea. Note that you might need to append '&campuscd=UBCO' to the end of the URL string for the course pages to display properly
# (eg. https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=101&campuscd=UBCO).
#
# Try loading webpages in a incognito browser window to see the page that the python code will recieve.
#
# In this assignment, you will implement a simple crawler to crawl and scrape UBC SSC web pages to grab your course schedule. Here are the steps of what you have to do:
#
# 1. Request the url https://courses.students.ubc.ca/cs/courseschedule?tname=subj-department&campuscd=UBCO&dept=DATA&pname=subjarea;
# 2. Create a `BeautifulSoup` object from the retrieved webpage;
# 3. Now, for each one of the courses in the page:
#     1. obtain the respective link;
#     2. retrieve the pre-reqs;

# %%
# Make request
page = requests.get(" https://courses.students.ubc.ca/cs/courseschedule?tname=subj-department&campuscd=UBCO&dept=DATA&pname=subjarea")

# Create BeautifulSoup object
soup = BeautifulSoup(page.text)

# TODO: Get courses
table = soup.find("table")
courses = []
links = []
for entry in table.find_all("a"):
    courses.append(entry.text)
    links.append(entry['href'])

df = pd.DataFrame({"course": courses,
                 "URL": links})
df
# TODO: Retrieve the page using the link to get pre-reqs
# Out:
#        course                                                URL
# 0    DATA 101  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 1    DATA 301  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 2    DATA 311  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 3    DATA 407  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 4    DATA 410  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 5   DATA 419A  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 6   DATA 448A  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 7    DATA 449  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 8    DATA 500  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 9    DATA 501  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 10   DATA 505  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 11   DATA 530  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 12   DATA 531  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 13   DATA 532  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 14   DATA 533  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 15   DATA 534  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 16   DATA 540  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 17   DATA 541  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 18   DATA 542  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 19   DATA 543  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 20   DATA 550  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 21   DATA 551  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 22   DATA 552  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 23   DATA 553  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 24   DATA 570  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 25   DATA 571  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 26   DATA 572  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 27   DATA 573  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 28   DATA 580  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 29   DATA 581  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 30   DATA 582  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 31   DATA 583  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 32   DATA 585  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 33   DATA 586  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 34   DATA 589  /cs/courseschedule?pname=subjarea&tname=subj-c...
# 35   DATA 599  /cs/courseschedule?pname=subjarea&tname=subj-c...

# %%
url = "https://courses.students.ubc.ca"
prereqs = []
titles = []
for course in courses:
    course_page = requests.get(url+table.find("a", text=course)["href"]+"&campuscd=UBCO")
    print("Scraping: ")
    print(url+table.find("a", text=course)["href"]+"&campuscd=UBCO")
    soup = BeautifulSoup(course_page.text)
    titles.append((soup.find("h4").text[9:]))
    if "Pre-reqs" in soup.find_all("p")[2].text:
        prereqs.append(soup.find_all("p")[2].text[14:]) #Subsetting removes the Pre-reqs:     part of the string
    else:
        prereqs.append("None")     
    time.sleep(0.5)
    
prereqDF = pd.DataFrame({"course": courses,
                         "Name": titles,
                   "Prerequisites": prereqs})
prereqDF
# Out:
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=101&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=301&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=311&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=407&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=410&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=419A&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=448A&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=449&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=500&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=501&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=505&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=530&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=531&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=532&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=533&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=534&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=540&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=541&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=542&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=543&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=550&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=551&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=552&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=553&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=570&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=571&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=572&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=573&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=580&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=581&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=582&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=583&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=585&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=586&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=589&campuscd=UBCO
# Scraping:
# https://courses.students.ubc.ca/cs/courseschedule?pname=subjarea&tname=subj-course&dept=DATA&course=599&campuscd=UBCO
#        course                                               Name  \
# 0    DATA 101                       Making Predictions with Data
# 1    DATA 301                     Introduction to Data Analytics
# 2    DATA 311                                   Machine Learning
# 3    DATA 407                                Sampling and Design
# 4    DATA 410           Regression and Generalized Linear Models
# 5   DATA 419A          Topics in Data Science - TOPICS DATA SCIE
# 6   DATA 448A   Directed Studies in Data Science - DIR ST DAT...
# 7    DATA 449                                     Honours Thesis
# 8    DATA 500       Communication and Consulting in Data Science
# 9    DATA 501                                     Data Analytics
# 10   DATA 505                           Modelling and Simulation
# 11   DATA 530               Computing Platforms for Data Science
# 12   DATA 531                       Programming for Data Science
# 13   DATA 532                      Algorithms and Data Structure
# 14   DATA 533                 Collaborative Software Development
# 15   DATA 534                            Web and Cloud Computing
# 16   DATA 540                       Databases and Data Retrieval
# 17   DATA 541                            Scripting and Reporting
# 18   DATA 542                                     Data Wrangling
# 19   DATA 543                                    Data Collection
# 20   DATA 550                                          Dataviz I
# 21   DATA 551                                         Dataviz II
# 22   DATA 552                    Communication and Argumentation
# 23   DATA 553          Privacy, Security and Professional Ethics
# 24   DATA 570                               Predictive Modelling
# 25   DATA 571                      Resampling and Regularization
# 26   DATA 572                                Supervised Learning
# 27   DATA 573          Unsupervised and Semi-supervised Learning
# 28   DATA 580                         Modelling and Simulation I
# 29   DATA 581                        Modelling and Simulation II
# 30   DATA 582                                 Bayesian Inference
# 31   DATA 583                      Advanced Predictive Modelling
# 32   DATA 585                                       Optimization
# 33   DATA 586                          Advanced Machine Learning
# 34   DATA 589                                      Special Topic
# 35   DATA 599                                           Capstone
#
#                                         Prerequisites
# 0                                                None
# 1    (Either (a) third-year standing, or (b) one o...
# 2   Either (a) STAT 230 or (b) a score more than 7...
# 3     One of STAT 230, PSYO 372, BIOL 202, ECON 327.
# 4                                          DATA 311.
# 5                             (Fourth-year standing.)
# 6    (Third-year standing in the Data Science majo...
# 7    (Fourth-year standing and permission of the d...
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                         DATA 532.
# 15                                               None
# 16                                         DATA 531.
# 17                                               None
# 18              All of DATA 532, DATA 540, DATA 541.
# 19                        All of DATA 540, DATA 570.
# 20                        All of DATA 530, DATA 531.
# 21              All of DATA 534, DATA 543, DATA 550.
# 22                                               None
# 23                                               None
# 24                                         DATA 580.
# 25                                         DATA 570.
# 26                                         DATA 571.
# 27                                         DATA 572.
# 28                                               None
# 29                                         DATA 580.
# 30                        All of DATA 572, DATA 581.
# 31                        All of DATA 572, DATA 581.
# 32                                         DATA 580.
# 33                                         DATA 580.
# 34                                         DATA 543.
# 35                        All of DATA 583, DATA 586.

# %% [markdown]
# # (Optional) Exercise 2
#
# In this exercise you will use the [`Scrapy`](https://docs.scrapy.org/en/latest/intro/tutorial.html) package to do the scrapping you did in Exercise 1. This cannot be done in Jupyter notebook, so check the file `lab1_question2.md` in lab1 folder for instructions.

# %% [markdown]
# # (Optional) Exercise 3
#
# Taking this to the next level, you could point your scraping up one level to this page: https://courses.students.ubc.ca/cs/courseschedule?tname=subj-all-departments&pname=subjarea&campuscd=UBCO
# Crawl through _all_ subjects and _all_ courses and report the course with the largest number of students enrolled.

# %% [markdown]
# # Exercise 4
#
# All the Game of Thrones episodes are listed, by season, in the following URL: https://en.wikipedia.org/wiki/List_of_Game_of_Thrones_episodes
#
# Unfortunately, the running time of each episode is not available. However, in the link provided for each episodes (e.g., https://en.wikipedia.org/wiki/Dragonstone_(Game_of_Thrones)) there is the running time of the respective episode. Collect the episodes' titles, season, number of U.S. viewers, and running time from wikipedia and create a pandas dataframe with the information collected.

# %%
url = "https://en.wikipedia.org"
eps = []
runtimes = []
seasons = []
viewers = []
GoT = requests.get("https://en.wikipedia.org/wiki/List_of_Game_of_Thrones_episodes")
GotSoup = BeautifulSoup(GoT.text)
for ep in (GotSoup.find_all("td", class_ = "summary")):
    try:
        ep.find("a")["href"] # The non-episode specials don't have links, so this makes it run only on episodes
        # Get Episode names and viewer numbers from summary page
        episode = ep.text[1:-1] #Removes parentheses
        viewer = ep.parent.findAll("td")[5].text
        print(episode,"    Scraping:")
        print(url+ep.find("a")["href"])
        # Request and BeautifulSoup
        ep_pg = requests.get(url+ep.find("a")["href"])
        soup = BeautifulSoup(ep_pg.text)
        info = soup.find("table", class_ = "infobox")
        # Get Runtime and season number from episode page
        runtime = info.find_all(text = re.compile('minutes'))
        season = info.find_all(text = re.compile('Season'))
        # Append episode info to our lists
        eps.append(episode)
        runtimes.append(runtime[0])
        seasons.append(season[0])
        viewers.append(viewer[:-4])
    except: # The special episodes don't have a hyperlink
        pass
# Out:
# Winter Is Coming     Scraping:
# https://en.wikipedia.org/wiki/Winter_Is_Coming
# The Kingsroad     Scraping:
# https://en.wikipedia.org/wiki/The_Kingsroad
# Lord Snow     Scraping:
# https://en.wikipedia.org/wiki/Lord_Snow
# Cripples, Bastards, and Broken Things     Scraping:
# https://en.wikipedia.org/wiki/Cripples,_Bastards,_and_Broken_Things
# The Wolf and the Lion     Scraping:
# https://en.wikipedia.org/wiki/The_Wolf_and_the_Lion
# A Golden Crown     Scraping:
# https://en.wikipedia.org/wiki/A_Golden_Crown
# You Win or You Die     Scraping:
# https://en.wikipedia.org/wiki/You_Win_or_You_Die
# The Pointy End     Scraping:
# https://en.wikipedia.org/wiki/The_Pointy_End
# Baelor     Scraping:
# https://en.wikipedia.org/wiki/Baelor
# Fire and Blood     Scraping:
# https://en.wikipedia.org/wiki/Fire_and_Blood_(Game_of_Thrones)
# The North Remembers     Scraping:
# https://en.wikipedia.org/wiki/The_North_Remembers
# The Night Lands     Scraping:
# https://en.wikipedia.org/wiki/The_Night_Lands
# What Is Dead May Never Die     Scraping:
# https://en.wikipedia.org/wiki/What_Is_Dead_May_Never_Die
# Garden of Bones     Scraping:
# https://en.wikipedia.org/wiki/Garden_of_Bones
# The Ghost of Harrenhal     Scraping:
# https://en.wikipedia.org/wiki/The_Ghost_of_Harrenhal
# The Old Gods and the New     Scraping:
# https://en.wikipedia.org/wiki/The_Old_Gods_and_the_New
# A Man Without Honor     Scraping:
# https://en.wikipedia.org/wiki/A_Man_Without_Honor
# The Prince of Winterfell     Scraping:
# https://en.wikipedia.org/wiki/The_Prince_of_Winterfell
# Blackwater     Scraping:
# https://en.wikipedia.org/wiki/Blackwater_(Game_of_Thrones)
# Valar Morghulis     Scraping:
# https://en.wikipedia.org/wiki/Valar_Morghulis
# Valar Dohaeris     Scraping:
# https://en.wikipedia.org/wiki/Valar_Dohaeris
# Dark Wings, Dark Words     Scraping:
# https://en.wikipedia.org/wiki/Dark_Wings,_Dark_Words
# Walk of Punishment     Scraping:
# https://en.wikipedia.org/wiki/Walk_of_Punishment
# And Now His Watch Is Ended     Scraping:
# https://en.wikipedia.org/wiki/And_Now_His_Watch_Is_Ended
# Kissed by Fire     Scraping:
# https://en.wikipedia.org/wiki/Kissed_by_Fire
# The Climb     Scraping:
# https://en.wikipedia.org/wiki/The_Climb_(Game_of_Thrones)
# The Bear and the Maiden Fair     Scraping:
# https://en.wikipedia.org/wiki/The_Bear_and_the_Maiden_Fair
# Second Sons     Scraping:
# https://en.wikipedia.org/wiki/Second_Sons
# The Rains of Castamere     Scraping:
# https://en.wikipedia.org/wiki/The_Rains_of_Castamere
# Mhysa     Scraping:
# https://en.wikipedia.org/wiki/Mhysa
# Two Swords     Scraping:
# https://en.wikipedia.org/wiki/Two_Swords_(Game_of_Thrones)
# The Lion and the Rose     Scraping:
# https://en.wikipedia.org/wiki/The_Lion_and_the_Rose
# Breaker of Chains     Scraping:
# https://en.wikipedia.org/wiki/Breaker_of_Chains
# Oathkeeper     Scraping:
# https://en.wikipedia.org/wiki/Oathkeeper
# First of His Name     Scraping:
# https://en.wikipedia.org/wiki/First_of_His_Name
# The Laws of Gods and Men     Scraping:
# https://en.wikipedia.org/wiki/The_Laws_of_Gods_and_Men
# Mockingbird     Scraping:
# https://en.wikipedia.org/wiki/Mockingbird_(Game_of_Thrones)
# The Mountain and the Viper     Scraping:
# https://en.wikipedia.org/wiki/The_Mountain_and_the_Viper
# The Watchers on the Wall     Scraping:
# https://en.wikipedia.org/wiki/The_Watchers_on_the_Wall
# The Children     Scraping:
# https://en.wikipedia.org/wiki/The_Children_(Game_of_Thrones)
# The Wars to Come     Scraping:
# https://en.wikipedia.org/wiki/The_Wars_to_Come
# The House of Black and White     Scraping:
# https://en.wikipedia.org/wiki/The_House_of_Black_and_White
# High Sparrow     Scraping:
# https://en.wikipedia.org/wiki/High_Sparrow_(Game_of_Thrones_episode)
# Sons of the Harpy     Scraping:
# https://en.wikipedia.org/wiki/Sons_of_the_Harpy
# Kill the Boy     Scraping:
# https://en.wikipedia.org/wiki/Kill_the_Boy
# Unbowed, Unbent, Unbroken     Scraping:
# https://en.wikipedia.org/wiki/Unbowed,_Unbent,_Unbroken
# The Gift     Scraping:
# https://en.wikipedia.org/wiki/The_Gift_(Game_of_Thrones)
# Hardhome     Scraping:
# https://en.wikipedia.org/wiki/Hardhome
# The Dance of Dragons     Scraping:
# https://en.wikipedia.org/wiki/The_Dance_of_Dragons
# Mother's Mercy     Scraping:
# https://en.wikipedia.org/wiki/Mother%27s_Mercy
# The Red Woman     Scraping:
# https://en.wikipedia.org/wiki/The_Red_Woman
# Home     Scraping:
# https://en.wikipedia.org/wiki/Home_(Game_of_Thrones)
# Oathbreaker     Scraping:
# https://en.wikipedia.org/wiki/Oathbreaker_(Game_of_Thrones)
# Book of the Stranger     Scraping:
# https://en.wikipedia.org/wiki/Book_of_the_Stranger
# The Door     Scraping:
# https://en.wikipedia.org/wiki/The_Door_(Game_of_Thrones)
# Blood of My Blood     Scraping:
# https://en.wikipedia.org/wiki/Blood_of_My_Blood
# The Broken Man     Scraping:
# https://en.wikipedia.org/wiki/The_Broken_Man
# No One     Scraping:
# https://en.wikipedia.org/wiki/No_One_(Game_of_Thrones)
# Battle of the Bastards     Scraping:
# https://en.wikipedia.org/wiki/Battle_of_the_Bastards
# The Winds of Winter     Scraping:
# https://en.wikipedia.org/wiki/The_Winds_of_Winter_(Game_of_Thrones)
# Dragonstone     Scraping:
# https://en.wikipedia.org/wiki/Dragonstone_(Game_of_Thrones_episode)
# Stormborn     Scraping:
# https://en.wikipedia.org/wiki/Stormborn
# The Queen's Justice     Scraping:
# https://en.wikipedia.org/wiki/The_Queen%27s_Justice
# The Spoils of War     Scraping:
# https://en.wikipedia.org/wiki/The_Spoils_of_War_(Game_of_Thrones)
# Eastwatch     Scraping:
# https://en.wikipedia.org/wiki/Eastwatch
# Beyond the Wall     Scraping:
# https://en.wikipedia.org/wiki/Beyond_the_Wall_(Game_of_Thrones)
# The Dragon and the Wolf     Scraping:
# https://en.wikipedia.org/wiki/The_Dragon_and_the_Wolf
# Winterfell     Scraping:
# https://en.wikipedia.org/wiki/Winterfell_(Game_of_Thrones_episode)
# A Knight of the Seven Kingdoms     Scraping:
# https://en.wikipedia.org/wiki/A_Knight_of_the_Seven_Kingdoms_(Game_of_Thrones)
# The Long Night     Scraping:
# https://en.wikipedia.org/wiki/The_Long_Night_(Game_of_Thrones)
# The Last of the Starks     Scraping:
# https://en.wikipedia.org/wiki/The_Last_of_the_Starks
# The Bells     Scraping:
# https://en.wikipedia.org/wiki/The_Bells_(Game_of_Thrones)
# The Iron Throne     Scraping:
# https://en.wikipedia.org/wiki/The_Iron_Throne_(Game_of_Thrones)

# %%
url = "https://en.wikipedia.org/wiki/The_Wolf_and_the_Lion"
ex = requests.get(url)
soup = BeautifulSoup(ex.text)
info = soup.find("table", class_ = "infobox")
info.find_all(text = re.compile('Season'))
# Out:
# ['Season\xa01']

# %%
url = "https://en.wikipedia.org/wiki/List_of_Game_of_Thrones_episodes"
ex = requests.get(url)
soup = BeautifulSoup(ex.text)
soup.findAll("tr", class_ = "vevent")[1].findAll("td")[5].text
# Out:
# '2.20[22]'

# %%
ep.parent.findAll("td")[5].text
# Out:
# [<td class="summary" style="text-align:left"><i>Game of Thrones: The Last Watch</i></td>,
#  <td style="text-align:center">May 26, 2019<span style="display:none"> (<span class="bday dtstart published updated">2019-05-26</span>)</span></td>,
#  <td style="text-align:center">1.63<sup class="reference" id="cite_ref-96"><a href="#cite_note-96">[96]</a></sup></td>]

# %%
df = pd.DataFrame({"Episode": eps,
                  "Runtime": runtimes,
                  "Season": seasons,
                  "U.S. Viewers (Millions)": viewers})
df
# Out:
#                                   Episode     Runtime    Season  \
# 0                        Winter Is Coming  62 minutes  Season 1
# 1                           The Kingsroad  56 minutes  Season 1
# 2                               Lord Snow  58 minutes  Season 1
# 3   Cripples, Bastards, and Broken Things  56 minutes  Season 1
# 4                   The Wolf and the Lion  55 minutes  Season 1
# ..                                    ...         ...       ...
# 68         A Knight of the Seven Kingdoms  58 minutes  Season 8
# 69                         The Long Night  82 minutes  Season 8
# 70                 The Last of the Starks  78 minutes  Season 8
# 71                              The Bells  78 minutes  Season 8
# 72                        The Iron Throne  79 minutes  Season 8
#
#    U.S. Viewers (Millions)
# 0                     2.22
# 1                     2.20
# 2                     2.44
# 3                     2.45
# 4                     2.58
# ..                     ...
# 68                   10.29
# 69                   12.02
# 70                   11.80
# 71                   12.48
# 72                   13.61
#
# [73 rows x 4 columns]
